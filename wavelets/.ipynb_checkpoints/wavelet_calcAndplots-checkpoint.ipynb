# %%
from matplotlib.gridspec import GridSpec

####Usual NumPy libraries
import numpy as np

###pandas
import pandas as pd

###writtem functions for analysing features
import alma_fd_functions as ff
from wave_python.waveletFunctions import wavelet, wave_signif
import crosswavelet_angle as cwsp


###Usual matplotlib tools
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.patches as patches
import matplotlib.animation as animation
from matplotlib.gridspec import GridSpec
import matplotlib.ticker as ticker
from matplotlib import cm as mplcm
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from matplotlib.transforms import offset_copy
from matplotlib.image import NonUniformImage

##PYWCT
###PYCWT
import pycwt as wavelet
from pycwt.helpers import find


###Datetime tools for timing managament
from datetime import datetime,timedelta

###AstroPy tools for FITS, units, etc
import astropy.units as u
from astropy.io import fits

###SkiImage tools for peaks detection and so on
from skimage.feature import peak_local_max
from skimage import data, img_as_float
from skimage import util
from skimage.measure import label as labelski

###Some SciPy tools for image processing
from scipy.ndimage.measurements import center_of_mass, label
import scipy.ndimage as scnd
from scipy import ndimage
from scipy import stats
import scipy as sp
from scipy import fftpack
from scipy import signal
from scipy.ndimage.filters import uniform_filter1d
from scipy.constants.constants import nu2lambda


###Importing Sunpy and its colormaps. This allow us to use same SDO colormaps
import sunpy
import sunpy.cm as cm
import sunpy.map

###Similarity measures
import similaritymeasures as sm

###Miscelaneous tools
import tqdm
import time
import importlib
from lmfit import Model
import glob
import random
import types
import idlsave
from radio_beam import Beam
from radio_beam import Beams

###Trackpy
import pims
import trackpy as tp

###Wavelet??

from piwavelet import piwavelet

import copy

###Extra
import warnings
warnings.filterwarnings('ignore')

import seaborn as sns
# sns.set_style('darkgrid')
# Out:
# WARNING: SunpyDeprecationWarning: The functionality of the sunpy.cm module is now in sunpy.visualization.colormaps as of SunPy 1.1. The ability to import sunpy.cm as a module will be removed in a future version of SunPy. [sunpy.cm]

# %% [markdown]
# # Ejemplo de MATLAB para probar el código de wavelet

# %%
# rng default;
t = np.arange(0,2,0.001)
t1 = copy.deepcopy(t)
t1[t1<0.5] = 0.
t1[t1>=1.1] = 0.

t2 = copy.deepcopy(t)
t2[t2<0.2] = 0.
t2[t2>=1.4] = 0.

x = np.cos(2*np.pi*10*t1) + np.cos(2*np.pi*50*t2) + .25*np.random.rand(len(t))

t3 = copy.deepcopy(t)
t3[t3<0.6] = 0.
t3[t3>=1.2] = 0.

t4 = copy.deepcopy(t)
t4[t4<0.4] = 0.
t4[t4>=1.6] = 0.

y = np.sin(2*np.pi*10*t3) + np.sin(2*np.pi*50*t4) + .35*np.random.rand(len(t))

len(t),len(x),len(y)
# Out:
# (2000, 2000, 2000)

# %%
fig, ax = plt.subplots(nrows=2,ncols=1,figsize=(10,5))

ax[0].plot(t,x)
ax[1].plot(t,y)

# %%
###
mother = 'morlet'
s1 = copy.deepcopy(x)
s2 = copy.deepcopy(y)
t1 = copy.deepcopy(t)
t2 = copy.deepcopy(t)

dt = np.diff(t1)[0]
n1 = t1.size
n2 = t2.size
n = min(n1, n2)

std1 = s1.std()
std2 = s2.std()

# I. Continuous wavelet transform
# ===============================

# Calculate the CWT of both normalized time series. The function wavelet.cwt
# returns a a list with containing [wave, scales, freqs, coi, fft, fftfreqs]
# variables.
exponente = int(np.log(t1[-1]/2)/np.log(2))
mother = wavelet.Morlet(6)          # Morlet mother wavelet with m=6
slevel = 0.95                       # Significance level
dj = 1/12                          # Twelve sub-octaves per octaves
s0 = -1#2 * dt                   # Starting scale, here 6 months
J = -1#exponente/dj  # 7 / dj                    # Seven powers of two with dj sub-octaves
if True:
    alpha1, _, _ = wavelet.ar1(s1)  # Lag-1 autocorrelation for red noise
    alpha2, _, _ = wavelet.ar1(s2)  # Lag-1 autocorrelation for red noise
else:
    alpha1 = alpha2 = 0.99           # Lag-1 autocorrelation for white noise

# The following routines perform the wavelet transform and siginificance
# analysis for two data sets.
W1, scales1, freqs1, coi1, _, _ = wavelet.cwt(s1/std1, dt, dj, s0, J, mother)
signif1, fft_theor1 = wavelet.significance(1.0, dt, scales1, 0, alpha1,
                                           significance_level=slevel,
                                           wavelet=mother)
W2, scales2, freqs2, coi2, _, _ = wavelet.cwt(s2/std2, dt, dj, s0, J, mother)
signif2, fft_theor2 = wavelet.significance(1.0, dt, scales2, 0, alpha2,
                                           significance_level=slevel,
                                           wavelet=mother)

power1 = (np.abs(W1)) ** 2             # Normalized wavelet power spectrum
power2 = (np.abs(W2)) ** 2             # Normalized wavelet power spectrum
period1 = 1/freqs1
period2 = 1/freqs2
sig95_1 = np.ones([1, n1]) * signif1[:, None]
sig95_1 = power1 / sig95_1             # Where ratio > 1, power is significant
sig95_2 = np.ones([1, n2]) * signif2[:, None]
sig95_2 = power2 / sig95_2             # Where ratio > 1, power is significant

# %%
# II. Cross-wavelet transform
# ===========================

# Due to the difference in the time series, the second signal has to be
# trimmed for the XWT process.
s2 = s2[np.argwhere((t2 >= min(t1)) & (t2 <= max(t1))).flatten()]

# Calculate the cross wavelet transform (XWT). The XWT finds regions in time
# frequency space where the time series show high common power. Torrence and
# Compo (1998) state that the percent point function -- PPF (inverse of the
# cumulative distribution function) -- of a chi-square distribution at 95%
# confidence and two degrees of freedom is Z2(95%)=3.999. However, calculating
# the PPF using chi2.ppf gives Z2(95%)=5.991. To ensure similar significance
# intervals as in Grinsted et al. (2004), one has to use confidence of 86.46%.
W12, cross_coi, freq, signif = wavelet.xwt(s1, s2, dt, dj=1/12, s0=-1, J=-1,
                                           significance_level=0.8646,
                                           wavelet='morlet', normalize=True)

cross_power = np.abs(W12)**2
cross_sig = np.ones([1, n]) * signif[:, None]
cross_sig = cross_power / cross_sig  # Power is significant where ratio > 1
cross_period = 1/freq

# Calculate the wavelet coherence (WTC). The WTC finds regions in time
# frequency space where the two time seris co-vary, but do not necessarily have
# high power.
WCT, aWCT, corr_coi, freq, sig = wavelet.wct(s1, s2, dt, dj=1/12, s0=-1, J=-1,
                                             significance_level=0.8646,
                                             wavelet='morlet', normalize=True,
                                             cache=False)

cor_sig = np.ones([1, n]) * sig[:, None]
cor_sig = np.abs(WCT) / cor_sig  # Power is significant where ratio > 1
cor_period = 1 / freq

# Calculates the phase between both time series. The phase arrows in the
# cross wavelet power spectrum rotate clockwise with 'north' origin.
# The relative phase relationship convention is the same as adopted
# by Torrence and Webster (1999), where in phase signals point
# upwards (N), anti-phase signals point downwards (S). If X leads Y,
# arrows point to the right (E) and if X lags Y, arrow points to the
# left (W).
angle = 0.5 * np.pi - aWCT
u, v = np.cos(angle), np.sin(angle)
# Out:
# Calculating wavelet coherence significance
# 100%|██████████| 300/300 [41:09<00:00,  8.23s/it]

# %%
cortar=2
# cut_per = np.where(np.abs(cross_period - (cross_period.max())/cortar)< 5)[0][0]
cut_per = len(cross_period)-1
cross_period[cut_per]
# Out:
# 2.048

# %%
# angle = aWCT
angle = 0.5 * np.pi - aWCT
u, v = np.cos(angle), np.sin(angle)

# %%
cut_per = len(cor_period)-15
cor_period[:cut_per]
# Out:
# array([0.002     , 0.00211893, 0.00224492, 0.00237841, 0.00251984,
#        0.00266968, 0.00282843, 0.00299661, 0.0031748 , 0.00336359,
#        0.00356359, 0.0037755 , 0.004     , 0.00423785, 0.00448985,
#        0.00475683, 0.00503968, 0.00533936, 0.00565685, 0.00599323,
#        0.0063496 , 0.00672717, 0.00712719, 0.00755099, 0.008     ,
#        0.0084757 , 0.0089797 , 0.00951366, 0.01007937, 0.01067872,
#        0.01131371, 0.01198646, 0.01269921, 0.01345434, 0.01425438,
#        0.01510199, 0.016     , 0.01695141, 0.01795939, 0.01902731,
#        0.02015874, 0.02135744, 0.02262742, 0.02397291, 0.02539842,
#        0.02690869, 0.02850876, 0.03020398, 0.032     , 0.03390282,
#        0.03591879, 0.03805463, 0.04031747, 0.04271488, 0.04525483,
#        0.04794583, 0.05079683, 0.05381737, 0.05701752, 0.06040796,
#        0.064     , 0.06780564, 0.07183757, 0.07610926, 0.08063495,
#        0.08542975, 0.09050967, 0.09589165, 0.10159367, 0.10763474,
#        0.11403504, 0.12081591, 0.128     , 0.13561128, 0.14367514,
#        0.15221851, 0.16126989, 0.1708595 , 0.18101934, 0.19178331,
#        0.20318733, 0.21526948, 0.22807007, 0.24163182, 0.256     ,
#        0.27122255, 0.28735028, 0.30443702, 0.32253979, 0.341719  ,
#        0.36203867, 0.38356661, 0.40637467, 0.43053896, 0.45614014,
#        0.48326365, 0.512     , 0.5424451 , 0.57470057, 0.60887404,
#        0.64507958, 0.68343801, 0.72407734, 0.76713322, 0.81274934,
#        0.86107793])

# %%
fig, ax2 = plt.subplots(figsize=(20,10))

levels2 = np.arange(0,1.01,5e-3).tolist()

CS2 = ax2.contourf(t2, cor_period[:cut_per], WCT[:cut_per,:], levels=levels2,cmap='jet')
# 
# 95# significance contour, levels at -99 (fake) and 1 (95# signif)
# ax2.contour(t2, cor_period[:cut_per], cor_sig[:cut_per,:], [-99, 1], colors='w',linewidths=[1,2])
# cone-of-influence, anything "below" is dubious
ax2.plot(t2, coi1[:], '--k',lw=3)

ax2.fill(np.concatenate([t2, t2[-1:] + dt, t2[-1:] + dt,
                           t2[:1] - dt, t2[:1] - dt]),
        np.concatenate([(corr_coi), [1e-9], (cor_period[:cut_per][-1:]),
                           (cor_period[:cut_per][-1:]), [1e-9]]),
        'k', alpha=0.3, hatch='x')

ax2.quiver(t2[::25], cor_period[:cut_per][::5], u[:cut_per,:][::5, ::25], v[:cut_per,:][::5, ::25], units='height',
           angles='uv', pivot='mid', linewidth=0.5, edgecolor='k',
           headwidth=10, headlength=10, headaxislength=5, minshaft=2,
           minlength=5)

divider2 = make_axes_locatable(ax2)
cax2 = divider2.append_axes('right', size='5%', pad=0.05)
fig.colorbar(CS2, cax=cax2, orientation='vertical')
cax2.set_ylabel('Coherence',fontsize=15)

ax2.set_yscale('log', basey=2, subsy=None)
ax2.set_ylim([np.min(cross_period[:cut_per]), np.max(cross_period[:cut_per])])
ax2.yaxis.set_major_formatter(ticker.ScalarFormatter())
ax2.ticklabel_format(axis='y', style='plain')
ax2.invert_yaxis()
plt.savefig('plots_v2/matlab_example_05pi_angle_inverty.png',dpi=150,bbox_inches = 'tight',pad_inches = 0.05)

# %%
angle = aWCT
# angle = 0.5 * np.pi - aWCT
u, v = np.cos(angle), np.sin(angle)

# %%
fig, ax2 = plt.subplots(figsize=(20,10))

levels2 = np.arange(0,1.01,5e-3).tolist()

CS2 = ax2.contourf(t2, cor_period[:cut_per], WCT[:cut_per,:], levels=levels2,cmap='jet')
# 
# 95# significance contour, levels at -99 (fake) and 1 (95# signif)
# ax2.contour(t2, cor_period[:cut_per], cor_sig[:cut_per,:], [-99, 1], colors='w',linewidths=[1,2])
# cone-of-influence, anything "below" is dubious
ax2.plot(t2, coi1[:], '--k',lw=3)

ax2.fill(np.concatenate([t2, t2[-1:] + dt, t2[-1:] + dt,
                           t2[:1] - dt, t2[:1] - dt]),
        np.concatenate([(corr_coi), [1e-9], (cor_period[:cut_per][-1:]),
                           (cor_period[:cut_per][-1:]), [1e-9]]),
        'k', alpha=0.3, hatch='x')

ax2.quiver(t2[::25], cor_period[:cut_per][::5], u[:cut_per,:][::5, ::25], v[:cut_per,:][::5, ::25], units='height',
           angles='uv', pivot='mid', linewidth=0.5, edgecolor='k',
           headwidth=10, headlength=10, headaxislength=5, minshaft=2,
           minlength=5)

divider2 = make_axes_locatable(ax2)
cax2 = divider2.append_axes('right', size='5%', pad=0.05)
fig.colorbar(CS2, cax=cax2, orientation='vertical')
cax2.set_ylabel('Coherence',fontsize=15)

ax2.set_yscale('log', basey=2, subsy=None)
ax2.set_ylim([np.min(cross_period[:cut_per]), np.max(cross_period[:cut_per])])
ax2.yaxis.set_major_formatter(ticker.ScalarFormatter())
ax2.ticklabel_format(axis='y', style='plain')
ax2.invert_yaxis()

plt.savefig('plots_v2/matlab_example_org_angle_inverty.png',dpi=150,bbox_inches = 'tight',pad_inches = 0.05)

# %%
fig, ax = plt.subplots(nrows=2,ncols=1,figsize=(10,5))

ax[0].plot(t1,s1)
ax[1].plot(t2,s2)
ax[0].set_title('X')
ax[1].set_title('Y')
ax[1].set_ylabel('time [s]')

plt.savefig('plots_v2/matlab_example_signals.png',dpi=150,bbox_inches = 'tight',pad_inches = 0.05)
